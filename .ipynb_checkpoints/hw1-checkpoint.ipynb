# %%
import pandas as pd
import numpy as np
import random
from scipy.stats import norm
import matplotlib.pyplot as plt

# %%
def simulate(T, sig_0, P_0, del_t, num_sim):
    t = 0
    prices = [P_0]
    log_price = [np.log(P_0)]
    while t < num_sim: 
        curr_y = log_price[-1]
        w = np.random.normal(0, 1, 1)[0]
        del_w = w*np.sqrt(del_t)
        # get sig_t    
        intgr = 0.
        if T > len(prices):
            curr_T = len(prices)
        else:
            curr_T = T
        if t == 0:
            sig_t = sig_0
        else:  
            for tau in range(1, curr_T):
                intgr += (g/((sig_0**2) * (tau**lamb))) * ((curr_y - log_price[-tau])**2)
            sig_t = sig_0 * np.sqrt(1.+intgr)
#             print 'sig_t at t ', t, 'is: ', sig_t
        y_next = sig_t*del_w + curr_y
        log_price.append(y_next)
        prices.append(np.exp(y_next))
        t += 1
    return prices, log_price

# %%
import quandl
quandl.ApiConfig.api_key = "YsgeJmyZtvDmyVdYinwf"
data = quandl.get_table('WIKI/PRICES', \
                        qopts = { 'columns': ['ticker', 'date', 'close'] }, \
                        ticker = ['MSFT'], \
                        date = { 'gte': '2006-01-01', 'lte': '2016-12-31' })
print(data.shape)
data.head()
# Out:
# (2769, 3)
#      ticker       date  close
# None
# 0      MSFT 2006-01-03  26.84
# 1      MSFT 2006-01-04  26.97
# 2      MSFT 2006-01-05  26.99
# 3      MSFT 2006-01-06  26.91
# 4      MSFT 2006-01-09  26.86

# %%
# %matplotlib inline
import seaborn as sns
sns.mpl.rcParams['figure.figsize'] = (10.0, 6.0)
sns.mpl.rcParams['savefig.dpi'] = 90
data.plot(x='date', y='close')
plt.title('MSFT Price')
plt.savefig('msft_price.png')

# %%
# plot log_returns
price = data
# log_return = log(pi/pj)
log_pj = list(np.log(price['close']))
log_pi = log_pj[1:]
log_pi.append(0)
assert len(log_pi) == len(log_pj)
price['log_ret'] = np.array(log_pi) - np.array(log_pj)
price = price[:-1]
price.plot(x='date',y = 'log_ret')
plt.title('MSFT Log Return')
plt.savefig('msft_log_ret.png')

# %%
# simulation model setup
T = 300
num_sim = price.shape[0] - 1 # -P0
g = 0.85
lamb = 1.15
sig_0 = 0.015
P_0 = price['close'][0] # initial price
del_t = 1./252. # 1 day

# prices_sim, log_price_sim = simulate(T, sig_0, P_0, del_t, num_sim)
# price['prices_sim'] = prices_sim
# price.plot(x='date',y = 'prices_sim')
# print np.argwhere(np.isnan([prices_sim]))

# price['prices_sim'] = prices_sim[:len(price)]
price.plot(x='date',y = 'prices_sim')
plt.title('Simulated Price')
plt.savefig('price_sim.png')

# %%
sns.distplot(price['prices_sim'])
# sns.distplot(price['close'])
# plt.title('MSFT Price Histogram')
plt.title('Simulated Price Histogram')
plt.savefig('price_sim_hist.png')

# %%
plot log_returns

log_return = log(pi/pj)
log_pj = list(np.log(price['prices_sim']))
log_pi = log_pj[1:]
log_pi.append(0)
assert len(log_pi) == len(log_pj)
price['log_ret_sim'] = np.array(log_pi) - np.array(log_pj)
price = price[:-1]
price.plot(x='date',y = 'log_ret_sim')
plt.title('Simulated Log Price Return')
plt.savefig('log_ret_sim.png')

# %%
sig_0 = np.std(price['log_ret'])
mu = np.mean(price['log_ret'])

sig_0_sim = np.std(price['log_ret_sim'])
mu_sim = np.mean(price['log_ret_sim'])

print (sig_0, mu)
print (sig_0_sim, mu_sim)

# check for fat tails for simulated data

price['normal_log_ret'] = list(mu_sim+sig_0_sim*np.random.normal(size=len(price)))

sns.mpl.rcParams['figure.figsize'] = (10.0, 6.0)
sns.mpl.rcParams['savefig.dpi'] = 90

import warnings
warnings.filterwarnings('ignore')
# Out:
# (0.01745295744088707, 0.0003120117004843914)
# (0.001127632556640398, 9.318248995140112e-06)

# %%
# fattail on msft data
# price['normal_log_ret_msft'] = list(mu+sig_0*np.random.normal(size=len(price)))
fig, ax = plt.subplots()
# sns.distplot(price['log_ret'], ax = ax)
# sns.distplot(price['normal_log_ret'],ax = ax)
sns.kdeplot(price['log_ret'],shade=True,ax=ax)
sns.kdeplot(price['normal_log_ret_msft'], shade=True,ax=ax)
# plt.xlim(-0.005, -0.002)
plt.title('MSFT Log Return VS. Normal Distribution')
plt.savefig('MSFT_logret_vs_normal_big.png')

# %%
# fattail on msft data zoom in 

# price['normal_log_ret_msft'] = list(mu+sig_0*np.random.normal(size=len(price)))
fig, ax = plt.subplots()
# sns.distplot(price['log_ret'], ax = ax)
# sns.distplot(price['normal_log_ret'],ax = ax)
sns.kdeplot(price['log_ret'],shade=True,ax=ax)
sns.kdeplot(price['normal_log_ret_msft'], shade=True,ax=ax)
plt.xlim(-0.1, -0.03)
plt.ylim(0, 5)
plt.title('MSFT Log Return VS. Normal Distribution Tail Zoom In')
plt.savefig('MSFT_logret_vs_normal_small.png')

# %%
# fattail zoom in

fig, ax = plt.subplots()
# sns.distplot(price['log_ret'], ax = ax)
# sns.distplot(price['normal_log_ret'],ax = ax)
sns.kdeplot(price['log_ret_sim'],shade=True,ax=ax)
sns.kdeplot(price['normal_log_ret'], shade=True,ax=ax)
# plt.xlim(-0.005, -0.002)
plt.title('Simulated Log Return VS. Normal Distribution')
plt.savefig('logret_vs_normal_big.png')

# %%
# fattail zoom in

fig, ax = plt.subplots()
# sns.distplot(price['log_ret'], ax = ax)
# sns.distplot(price['normal_log_ret'],ax = ax)
sns.kdeplot(price['log_ret_sim'],shade=True,ax=ax)
sns.kdeplot(price['normal_log_ret'], shade=True,ax=ax)
plt.xlim(-0.005, -0.0025)
plt.ylim(0, 40)
plt.title('Simulated Log Return VS. Normal Distribution Tail Zoom In')
plt.savefig('logret_vs_normal_zoomin.png')

# %%
# test for autocorrelation on MSFT data

y = price['log_ret']**2
y = y - np.mean(y)
norm = np.sum(y ** 2)
correlated = np.correlate(y, y, mode='full')/norm
idx = np.argsort(correlated)[-1]
# np.corrcoef(y)
# print 'highest correlation is at index ', idx, 'which has value: ', correlated[idx]
plt.plot(correlated)
plt.title('Correlation on Squared MSFT Log Return')
plt.savefig('corr_msft.png')

# %%
# test for autocorrelation on MSFT data

y = price['log_ret']**2
y = y - np.mean(y)
norm = np.sum(y ** 2)
correlated = np.correlate(y, y, mode='full')/norm
idx = np.argsort(correlated)[-1]
# np.corrcoef(y)
# print 'highest correlation is at index ', idx, 'which has value: ', correlated[idx]
plt.plot(correlated)
# plt.xlim(2600,6000)
plt.ylim(0, 0.3)
plt.title('Rescaled Correlation on Squared MSFT Log Return')
plt.savefig('rescaled_corr_msft.png')

# %%
# test for autocorrelation

y = price['log_ret_sim']**2
y = y - np.mean(y)
norm = np.sum(y ** 2)
correlated = np.correlate(y, y, mode='full')/norm
idx = np.argsort(correlated)[-1]
# np.corrcoef(y)
# print 'highest correlation is at index ', idx, 'which has value: ', correlated[idx]
plt.plot(correlated)
plt.title('Correlation on Squared Simulated Log Return')
plt.savefig('corr_sim.png')

# %%
# test for autocorrelation

y = price['log_ret_sim']**2
y = y - np.mean(y)
norm = np.sum(y ** 2)
correlated = np.correlate(y, y, mode='full')/norm
idx = np.argsort(correlated)[-1]
# np.corrcoef(y)
# print 'highest correlation is at index ', idx, 'which has value: ', correlated[idx]
plt.plot(correlated)
# plt.xlim(2600,6000)
plt.ylim(0, 0.2)
plt.title('Correlation on Squared Simulated Log Return Zoom in')
plt.savefig('zoom_in_corr_sim.png')

# %%
price.head()
# Out:
#      ticker       date  close   log_ret  prices_sim  log_ret_sim  \
# None
# 0      MSFT 2006-01-03  26.84  0.004832   26.840000    -0.000185
# 1      MSFT 2006-01-04  26.97  0.000741   26.835033     0.002673
# 2      MSFT 2006-01-05  26.99 -0.002968   26.906866     0.000054
# 3      MSFT 2006-01-06  26.91 -0.001860   26.908310    -0.000745
# 4      MSFT 2006-01-09  26.86  0.005199   26.888257    -0.001429
#
#       normal_log_ret  normal_log_ret_msft
# None
# 0          -0.000055             0.005540
# 1          -0.000680            -0.011598
# 2           0.001180             0.001087
# 3           0.001115             0.002907
# 4          -0.000172            -0.009339
